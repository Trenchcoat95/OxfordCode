# %%
import numpy as np
from array import array
import os
import sys
import ROOT
from ROOT import TVectorD, TMatrix, TMath
from ROOT import TVector3, TGraphErrors, TFile, TTree, gRandom, gPad, gROOT, gVirtualX, kTRUE, kRed, TProfile, gStyle,TChain,TF1, TGraph
from IPython.display import clear_output

# %%
path = "/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/MCgarlite/6planes/"



filename0 = path+"muon_test_ana_kalman.root"

file0 = ROOT.TFile(filename0)


t0=file0.Get("t1s")

# %%
t0.GetEntry(0)

gr_par0_MC = ROOT.TGraph()
for i in range(t0.xyz_plane.size()): gr_par0_MC.SetPoint(i,i,t0.xyz_plane.at(i).Z())


cp0 = ROOT.TCanvas("myCanvasNamep0","The Canvas Titlep0",800,600)
#gr_par0.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par0_MC.SetMarkerStyle(31)
#gr_par0.SetMarkerStyle(31)
#gr_par0_forw.SetMarkerStyle(31)
gr_par0_MC.SetMarkerColor(2)
gr_par0_MC.Draw()
cp0.Draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb Cell 3' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000008?line=0'>1</a> t0.GetEntry(1)
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000008?line=2'>3</a> gr_par0_MC = ROOT.TGraph()
# ----> <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000008?line=3'>4</a> for i in range(t0.xyz_plane.size()): gr_par0_MC.SetPoint(i,i,t0.xyz_plane.at(i).Z())
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000008?line=6'>7</a> cp0 = ROOT.TCanvas("myCanvasNamep0","The Canvas Titlep0",800,600)
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000008?line=7'>8</a> #gr_par0.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
#
# AttributeError: 'TTree' object has no attribute 'xyz_plane'

# %%
t0.GetEntry(1)

gr_par0 = ROOT.TGraph()
for i in range(t0.parvect_bkw.size()): gr_par0.SetPoint(i,i,t0.parvect_bkw.at(t0.parvect_bkw.size()-i-1)[0])

gr_par0_forw = ROOT.TGraph()
for i in range(t0.parvect.size()): gr_par0_forw.SetPoint(i,i+1,t0.parvect.at(i)[0])

gr_par0_MC = ROOT.TGraph()
for i in range(t0.xyz_plane.size()): gr_par0_MC.SetPoint(i,i,t0.xyz_plane.at(i).Y())


cp0 = ROOT.TCanvas("myCanvasNamep0","The Canvas Titlep0",800,600)
gr_par0.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par0_MC.SetMarkerStyle(31)
gr_par0.SetMarkerStyle(31)
gr_par0_forw.SetMarkerStyle(31)
gr_par0_MC.SetMarkerColor(2)
gr_par0.SetMarkerColor(4)
gr_par0_forw.SetMarkerColor(3)
gr_par0_MC.Draw()
gr_par0.Draw("LPSAME")
gr_par0_forw.Draw("LPSAME")
cp0.Modified()
cp0.Update()

legend = ROOT.TLegend(0.1,0.8,0.4,0.9)
#legendtext = "Average y RMS: " + "{:.9f}".format(averageyRMS)
legend.AddEntry(gr_par0_forw,"Kalman Y Forward")
legend.AddEntry(gr_par0,"Kalman Y Backwards")
legend.AddEntry(gr_par0_MC,"MC Y")
legend.Draw()

cp0.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasNamep0

# %%
t0.GetEntry(1)

gr_par1 = ROOT.TGraph()
for i in range(t0.parvect_bkw.size()): gr_par1.SetPoint(i,i,t0.parvect_bkw.at(t0.parvect_bkw.size()-i-1)[1])

gr_par1_forw = ROOT.TGraph()
for i in range(t0.parvect.size()): gr_par1_forw.SetPoint(i,i+1,t0.parvect.at(i)[1])

gr_par1_MC = ROOT.TGraph()
for i in range(t0.xyz_plane.size()): gr_par1_MC.SetPoint(i,i,t0.xyz_plane.at(i).X())


cp1 = ROOT.TCanvas("myCanvasNamep1","The Canvas Titlep1",800,600)
gr_par1.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par1_MC.SetMarkerStyle(31)
gr_par1.SetMarkerStyle(31)
gr_par1_forw.SetMarkerStyle(31)
gr_par1_MC.SetMarkerColor(2)
gr_par1.SetMarkerColor(4)
gr_par1_forw.SetMarkerColor(3)
gr_par1_MC.Draw()
gr_par1.Draw("LPSAME")
gr_par1_forw.Draw("LPSAME")
cp1.Modified()
cp1.Update()

legend = ROOT.TLegend(0.1,0.8,0.4,0.9)
#legendtext = "Average y RMS: " + "{:.9f}".format(averageyRMS)
legend.AddEntry(gr_par1_forw,"Kalman X Forward")
legend.AddEntry(gr_par1,"Kalman X Backwards")
legend.AddEntry(gr_par1_MC,"MC X")
legend.Draw()

cp1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasNamep1

# %%
t0.GetEntry(1)

gr_par2 = ROOT.TGraph()
for i in range(t0.parvect_bkw.size()): gr_par2.SetPoint(i,i,t0.parvect_bkw.at(t0.parvect_bkw.size()-i-1)[2])

gr_par2_forw = ROOT.TGraph()
for i in range(t0.parvect.size()): gr_par2_forw.SetPoint(i,i+1,t0.parvect.at(i)[2])

gr_par2_MC = ROOT.TGraph()
for i in range(t0.invpT_plane.size()): gr_par2_MC.SetPoint(i,i,t0.sinphi_plane.at(i))


cp2 = ROOT.TCanvas("myCanvasNamep2","The Canvas Titlep2",800,600)
gr_par2.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par2_MC.SetMarkerStyle(31)
gr_par2.SetMarkerStyle(31)
gr_par2_forw.SetMarkerStyle(31)
gr_par2_MC.SetMarkerColor(2)
gr_par2.SetMarkerColor(4)
gr_par2_forw.SetMarkerColor(3)
gr_par2_MC.Draw()
gr_par2.Draw("LPSAME")
gr_par2_forw.Draw("LPSAME")
cp2.Modified()
cp2.Update()

legend = ROOT.TLegend(0.1,0.8,0.4,0.9)
#legendtext = "Average y RMS: " + "{:.9f}".format(averageyRMS)
legend.AddEntry(gr_par2_forw,"Kalman sin(#phi) Forward")
legend.AddEntry(gr_par2,"Kalman sin(#phi) Backwards")
legend.AddEntry(gr_par2_MC,"MC sin(#phi)")
legend.Draw()

cp2.Draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb Cell 6' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000004?line=6'>7</a> for i in range(t0.parvect.size()): gr_par2_forw.SetPoint(i,i+1,t0.parvect.at(i)[2])
#       <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000004?line=8'>9</a> gr_par2_MC = ROOT.TGraph()
# ---> <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000004?line=9'>10</a> for i in range(t0.invpT_plane.size()): gr_par2_MC.SetPoint(i,i,t0.sinphi_plane.at(i))
#      <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000004?line=12'>13</a> cp2 = ROOT.TCanvas("myCanvasNamep2","The Canvas Titlep2",800,600)
#      <a href='vscode-notebook-cell:/home/federico/Documents/Universita/Federico_2020-2021/OxfordCode/Kalman_Garlite/jupyter_notebooks/paramevol_MCgarlite_ana.ipynb#ch0000004?line=13'>14</a> gr_par2.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
#
# AttributeError: 'TTree' object has no attribute 'invpT_plane'

# %%
t0.GetEntry(1)

gr_par3 = ROOT.TGraph()
for i in range(t0.parvect_bkw.size()): gr_par3.SetPoint(i,i,t0.parvect_bkw.at(t0.parvect_bkw.size()-i-1)[3])

gr_par3_forw = ROOT.TGraph()
for i in range(t0.parvect.size()): gr_par3_forw.SetPoint(i,i+1,t0.parvect.at(i)[3])

gr_par3_MC = ROOT.TGraph()
for i in range(t0.invpT_plane.size()): gr_par3_MC.SetPoint(i,i,t0.tanlambda_plane.at(i))


#+gr_par3_MC.GetYaxis().SetRangeUser(-0.1078,-0.1074)

cp3 = ROOT.TCanvas("myCanvasNamep3","The Canvas Titlep3",800,600)
gr_par3.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par3_MC.SetMarkerStyle(31)
gr_par3.SetMarkerStyle(31)
gr_par3_forw.SetMarkerStyle(31)
gr_par3_MC.SetMarkerColor(2)
gr_par3.SetMarkerColor(4)
gr_par3_forw.SetMarkerColor(3)
gr_par3_MC.Draw()
gr_par3.Draw("LPSAME")
gr_par3_forw.Draw("LPSAME")
cp3.Modified()
cp3.Update()

legend = ROOT.TLegend(0.1,0.8,0.4,0.9)
#legendtext = "Average y RMS: " + "{:.9f}".format(averageyRMS)
legend.AddEntry(gr_par3_forw,"Kalman tan(#lambda) Forward")
legend.AddEntry(gr_par3,"Kalman tan(#lambda) Backwards")
legend.AddEntry(gr_par3_MC,"MC tan(#lambda)")
legend.Draw()

cp3.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasNamep3

# %%
t0.GetEntry(1)

gr_par4 = ROOT.TGraph()
for i in range(t0.parvect_bkw.size()): gr_par4.SetPoint(i,i,t0.parvect_bkw.at(t0.parvect_bkw.size()-i-1)[4])

gr_par4_forw = ROOT.TGraph()
for i in range(t0.parvect.size()): gr_par4_forw.SetPoint(i,i+1,t0.parvect.at(i)[4])

gr_par4_MC = ROOT.TGraph()
for i in range(t0.invpT_plane.size()): gr_par4_MC.SetPoint(i,i,t0.invpT_plane.at(i))


cp4 = ROOT.TCanvas("myCanvasNamep4","The Canvas Titlep4",800,600)
gr_par4.SetTitle("1/pT evolution : Real Seed, #DeltaE correction;point;(GeV/c)^{-1}")
gr_par4_MC.SetMarkerStyle(31)
gr_par4.SetMarkerStyle(31)
gr_par4_forw.SetMarkerStyle(31)
gr_par4_MC.SetMarkerColor(2)
gr_par4.SetMarkerColor(4)
gr_par4_forw.SetMarkerColor(3)
gr_par4_MC.Draw()
gr_par4.Draw("LPSAME")
gr_par4_forw.Draw("LPSAME")
cp4.Modified()
cp4.Update()

legend = ROOT.TLegend(0.1,0.8,0.4,0.9)
#legendtext = "Average y RMS: " + "{:.9f}".format(averageyRMS)
legend.AddEntry(gr_par4_forw,"Kalman q/pT Forward")
legend.AddEntry(gr_par4,"Kalman q/pT Backwards")
legend.AddEntry(gr_par4_MC,"MC q/pT")
legend.Draw()

cp4.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasNamep4

# %%
hsinphiresKalman   = ROOT.TH1D( 'hpsinphiKalman', 'p Residuals Kalman', 500, 0, 1)
mylandau = ROOT.TF1("mylandau","TMath::Landau(x,[0],[1],0)",0,0.5)
mylandau.SetParameters(0.1,0.015)
hsinphiresKalman.FillRandom("mylandau",10000)
cp5 = ROOT.TCanvas("myCanvasNamep5","The Canvas Titlep5",800,600)
mylandau.Draw()
cp5.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: myCanvasNamep5
